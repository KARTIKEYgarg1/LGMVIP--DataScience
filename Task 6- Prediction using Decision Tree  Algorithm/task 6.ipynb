# %% [markdown]
# # Prediction using Decision Tree  Algorithm

# %% [markdown]
# ## Iris dataset

# %%
import pandas as pd
iris=pd.read_csv("data/Iris.csv")
iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# # Seperating X and y

# %%
X = iris.iloc[:, 1:5]
y = iris.Species

# %%
X
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %% [markdown]
# ## Modelling

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(max_depth=2, random_state=42)
model.fit(X, y)
# Out:
# DecisionTreeClassifier(max_depth=2, random_state=42)

# %% [markdown]
# # Visualising

# %%
import sklearn.tree as tree
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(model, 
                   feature_names=X.columns,  
                   class_names=iris.Species,
                   filled=True)

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(y[130:], model.predict(X[130:])))
# Out:
# 0.9

# %% [markdown]
# ## Input new data

# %%
import numpy as np

print("Enter SepalLength(cm), SepalWidth(cm), PetalLength(cm), PetalWidth(cm)")
inp=list(map(int,input().split(" ")))
inp=np.array(inp).reshape(1,-1)
# Out:
# Enter SepalLength(cm), SepalWidth(cm), PetalLength(cm), PetalWidth(cm)
# 25 12 23 25

# %%
 model.predict(inp)[0]
# Out:
# C:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# 'Iris-virginica'
